# %%
from matplotlib import pyplot as plt
import numpy as np
# test
data_test = {}
data_train = {}
def get_data(i, is_train=True):
    if is_train:
        data_train[i] = np.load(f"/home/viki/Codes/MultiSource/3/multi_source_exp/MultiSourceExp/data/data_set_1/x{i}_train.npy")
    else:
        data_test[i] = np.load(f"/home/viki/Codes/MultiSource/3/multi_source_exp/MultiSourceExp/data/data_set_1/x{i}_test.npy")

for i in range(21):
    get_data(i)

print(len(data_train[20]))
plt.imshow(data_train[0][4])
# Out:
# 1000
